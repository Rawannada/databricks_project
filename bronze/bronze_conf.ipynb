# %% [markdown]
# #listing my fils

# %%
base_bath =  "/Volumes/dev_project/bronze/source_sys"
my_files = [
    {
        "path":f"{base_bath}/CUST_AZ12.csv",
        "table": "CUST_AZ12_row"
    }
    ,{
        "path":f"{base_bath}/LOC_A101.csv",
        "table": "LOC_A101_row"
    },
    {"path":f"{base_bath}/PX_CAT_G1V2.csv",
        "table": "PX_CAT_G1V2_row"
    },
    {"path":f"{base_bath}/cust_info.csv",
        "table": "cust_info_row"
    },
    {"path":f"{base_bath}/prd_info.csv",
        "table": "prd_info_row"
    },
    {"path":f"{base_bath}/sales_details.csv",
        "table": "sales_details_row"
    }
]
