# %% [markdown]
# #import my conf file

# %%
# %run ./bronze_conf

# %% [markdown]
# #loop in my list

# %%
for i in my_files:
      df = (spark.read .option ("headr","true")
      .option ("inferschema","true")
      .csv(i["path"]))
      df.write.mode("append").saveAsTable(f"dev_project.bronze.{i["table"]}")
