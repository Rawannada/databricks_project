# %% [markdown]
# #load my data into df

# %%
df = spark .table ("dev_project.bronze.sales_details_row")

# %% [markdown]
# #explore & transform

# %%
df.display()

# %%
df.write.mode("overwrite").saveAsTable("dev_project.silver.sales_details")
